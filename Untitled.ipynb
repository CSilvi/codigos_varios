# %%
import pandas as pd
import sqlite3
import matplotlib

# %%
csv = '2023.csv'
df = pd.read_csv(csv, index_col=0, sep=';', encoding='latin-1')
df
# Out:
#                               donde_estas_trabajando dedicacion  \
# estoy_trabajando_en
# Argentina                               Buenos Aires  Full-Time
# Argentina                                  Río Negro  Full-Time
# Argentina                               Buenos Aires  Full-Time
# Argentina            Ciudad Autónoma de Buenos Aires  Full-Time
# Argentina            Ciudad Autónoma de Buenos Aires  Full-Time
# ...                                              ...        ...
# Argentina                               Buenos Aires  Full-Time
# Argentina                               Buenos Aires  Full-Time
# Argentina            Ciudad Autónoma de Buenos Aires  Full-Time
# Argentina            Ciudad Autónoma de Buenos Aires  Full-Time
# Argentina            Ciudad Autónoma de Buenos Aires  Full-Time
#
#                                                       tipo_de_contrato  \
# estoy_trabajando_en
# Argentina                                                   Contractor
# ...

# %%
df_1 = df.iloc[:10]
df_1
# Out:
#                               donde_estas_trabajando dedicacion  \
# estoy_trabajando_en
# Argentina                               Buenos Aires  Full-Time
# Argentina                                  Río Negro  Full-Time
# Argentina                               Buenos Aires  Full-Time
# Argentina            Ciudad Autónoma de Buenos Aires  Full-Time
# Argentina            Ciudad Autónoma de Buenos Aires  Full-Time
# Argentina                               Buenos Aires  Full-Time
# Argentina                                    Córdoba  Full-Time
# Argentina            Ciudad Autónoma de Buenos Aires  Full-Time
# Argentina                                   San Luis  Part-Time
# Argentina                               Buenos Aires  Full-Time
#
#                               tipo_de_contrato  \
# estoy_trabajando_en
# Argentina                           Contractor
# Argentina                           Contractor
# Argentina            Staff (planta permanente)
# ...

# %%
list(df.columns)
# Out:
# ['donde_estas_trabajando',
#  'dedicacion',
#  'tipo_de_contrato',
#  'ultimo_salario_mensual_o_retiro_bruto_en_tu_moneda_local',
#  'ultimo_salario_mensual_o_retiro_neto_en_tu_moneda_local',
#  'pagos_en_dolares',
#  'si_tu_sueldo_esta_dolarizado_cual_fue_el_ultimo_valor_del_dolar_que_tomaron',
#  'recibis_algun_tipo_de_bono',
#  'a_que_esta_atado_el_bono',
#  'tuviste_actualizaciones_de_tus_ingresos_laborales_durante_2023',
#  'de_que_fue_el_ajuste_total_acumulado',
#  'en_que_mes_fue_el_ultimo_ajuste',
#  'como_consideras_que_estan_tus_ingresos_laborales_comparados_con_el_semestre_anterior',
#  'contas_con_beneficios_adicionales',
#  'que_tan_conforme_estas_con_tus_ingresos_laborales',
#  'estas_buscando_trabajo',
#  'trabajo_de',
#  'anos_de_experiencia',
#  'antiguedad_en_la_empresa_actual',
#  'tiempo_en_el_puesto_actual',
#  'cuantas_personas_a_cargo_tenes',
#  'plataformas_que_utilizas_en_tu_puesto_actual',
# ...
